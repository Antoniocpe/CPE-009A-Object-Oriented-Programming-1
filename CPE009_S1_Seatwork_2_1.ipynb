# %% [markdown]
# <a href="https://colab.research.google.com/github/Antoniocpe/CPE-009A-Object-Oriented-Programming-1/blob/main/CPE009_S1_Seatwork_2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# We want to create a python code for a grading scheme

# Create a function to accept a number of activities
# Compute for the score vs total
# Return the average grade of the student in %
def termCrit(actNumber):
  rawScore = []
  totalScore = []

  for i in range(0, actNumber):
    inputScore = float(input("Score: "))
    inputTotal = float(input("Total: "))

    print("score vs total: ", inputTotal - inputScore)

    if inputScore > inputTotal:
      print("\nInvalid Scores.\n")
      inputScore, inputTotal = 0,0
      break
    else:
      rawScore.append(inputScore)
      totalScore.append(inputTotal)

  grade = sum(rawScore) / sum(totalScore)
  grade = grade * 100
  print("score %: ", grade)
  return grade

# %%
# Create a function for the class standing per term
def termCS():
  print("Hands-on Activities: ")
  termHOA = termCrit(int(input("How many hands-on activities this term?")))

  print("Quizzes:")
  termQuiz = termCrit(int(input("How many quizzes this term?")))

  print("Assignment: ")
  termAss = termCrit(int(input("How many assignments?")))


  grade = (0.5 * termHOA) + (0.3 * termQuiz) + (0.2 * termAss)
  return grade

# %%
# Create a function to compute the term grade
def termGrade():
  print("Computing for the term grade.")
  examRaw = float(input("Exam Score: "))
  examTotal = float(input("Exam Total: "))
  examGrade = (examRaw/examTotal) * 100

  CSgrade = termCS()

  grade = (0.5 * examGrade) + (0.5 * CSgrade)
  return grade

# %%
# Create a function to compute for the grades in the semester
def semesterGrade():
  print("Prelim Grade")
  prelimGrade = termGrade()

  print("Prelim Grade: ", prelimGrade)
  print("Converted Grade: ", convertGrade(prelimGrade))

  print("\nMidterm Grade")
  midtermGrade = termGrade()
  finalMG = (1/3)*prelimGrade + (2/3)*midtermGrade

  print("Final Grade: ", midtermGrade)
  print("Converted Grade: ", convertGrade(midtermGrade))

  print("\nFinal Grade")
  finalGrade = termGrade()
  finalFG = (1/3)*finalMG + (2/3)*finalGrade

  print("Final Grade: ", finalFG)
  print("Converted Grade: ", convertGrade(finalFG))

# %%
def convertGrade(finalGrade):

  if finalGrade >= 98.0: return 1.00
  elif finalGrade >= 95.0: return 1.25
  elif finalGrade >= 92.0: return 1.5
  elif finalGrade >= 89.0: return 1.75
  elif finalGrade >= 86.0: return 2.0
  elif finalGrade >= 83.0: return 2.25
  elif finalGrade >= 80.0: return 2.5
  elif finalGrade >= 75.0: return 2.75
  elif finalGrade < 75.0: return 3.0
  #The class should add everything else

  #based on TIP grading scheme

# %% [markdown]
# PRELIM:
# EXAM = 50/50 = 100%
# HOA = 90/100 = 90
# QUIZ = 10/10 = 100%
# ASSIGNMENT = 95/100 = 95%
#
# GRADE =
#
# MIDTERM:
# EXAM = 50/60
# HOA
# QUIZ
# ASSIGNMENT
#
# FINAL:
# EXAM = 100/100
# HOA
# QUIZ
# ASSIGNMENT

# %%
1# Driver Code

# Trial 1
print(convertGrade(semesterGrade()))

# Trial 2
# Trial 3
# Out:
# Prelim Grade
# Computing for the term grade.
# Exam Score: 50
# Exam Total: 50
# Hands-on Activities:
# How many hands-on activities this term?1
# Score: 10
# Total: 10
# score vs total:  0.0
# score %:  100.0
# Quizzes:
# How many quizzes this term?1
# Score: 10
# Total: 10
# score vs total:  0.0
# score %:  100.0
# Assignment:
# How many assignments?1
# Score: 90
# Total: 100
# score vs total:  10.0
# score %:  90.0
# Prelim Grade:  99.0
# Converted Grade:  1.0
#
# Midterm Grade
# Computing for the term grade.
# Exam Score: 40
# Exam Total: 50
# Hands-on Activities:
# How many hands-on activities this term?1
# Score: 30
# Total: 40
# score vs total:  10.0
# score %:  75.0
# Quizzes:
# How many quizzes this term?1
# Score: 15
# Total: 20
# score vs total:  5.0
# score %:  75.0
# Assignment:
# How many assignments?1
# Score: 85
# Total: 100
# score vs total:  15.0
# score %:  85.0
# Final Grade:  78.5
# Converted Grade:  2.75
#
# Final Grade
# Computing for the term grade.
# Exam Score: 90
# Exam Total: 100
# Hands-on Activities:
# How many hands-on activities this term?1
# Score: 34
# Total: 35
# score vs total:  1.0
# score %:  97.14285714285714
# Quizzes:
# How many quizzes this term?2
# Score: 5
# Total: 10
# score vs total:  5.0
# Score: 6
# Total: 6
# score vs total:  0.0
# score %:  68.75
# Assignment:
# How many assignments?1
# Score: 45
# Total: 50
# score vs total:  5.0
# score %:  90.0
# Final Grade:  87.50992063492063
# Converted Grade:  2.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1293819119.py in <cell line: 0>()
#       2
#       3 # Trial 1
# ----> 4 print(convertGrade(semesterGrade()))
#       5
#       6 # Trial 2
#
# /tmp/ipython-input-539676027.py in convertGrade(finalGrade)
#       1 def convertGrade(finalGrade):
#       2
# ----> 3   if finalGrade >= 98.0: return 1.00
#       4   elif finalGrade >= 95.0: return 1.25
#       5   elif finalGrade >= 92.0: return 1.5
#
# TypeError: '>=' not supported between instances of 'NoneType' and 'float'

# %% [markdown]
# **What is the difference from the code you created?**
#
# <Answer here>
