# %% [markdown]
# <a href="https://colab.research.google.com/github/Antoniocpe/CPE-009A-Object-Oriented-Programming-1/blob/main/Python_Fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python indentation

# %%
if 10 > 2:
  print("ten is greater than two")

# %% [markdown]
# Python comments

# %%
#this is a commnet
print("hello world")

# %% [markdown]
# variable naming conventions

# %%
size = float(10)
size_2 = int(5)
Size = 'a'

print(Size)
# Out:
# a

# %%
b= "sally"
b = int(4)
print(b)

b = float(4)
print(b)
# Out:
# 4
# 4.0

# %% [markdown]
# Type() function

# %%
x = 5
y = "John"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# double quotes or signle quotes

# %%
y = "John"
y = 'John'

# %% [markdown]
# case sensitive

# %%
a = 4
A = "Sally"
#A will not overwrite a
print(A)
# Out:
# Sally

# %% [markdown]
# multiple variables

# %%
x,y,z = "one", "two", "three"
print(x)
print(y)
print(z)
# Out:
# one
# two
# three

# %% [markdown]
# one value to multiple variables

# %%
x = y = z = "four"
print(x)
print(y)
print(z)

# %% [markdown]
# Output variables

# %%
x = "enjoying"
print("Python programming is" + x)

# %%
x = "Python is "
y = "enjoying"
z = x + y
print(z)

# %% [markdown]
# arithmetic operations

# %%
x = 5
y = 3
print(x + y)

x = 5 - 3 #2
y = (3 * 5) // 2 #7
z = 21 % 4 #1
sum = x + y + z / 2 ** 3 #<-- 8
sum
# Out:
# 8
# 9.125

# %% [markdown]
# assignment operators

# %%
#1
x = 5
print(x)

#2
x += 3
print(x)

#3
x = 5
x -= 3
print(x)

#4
x = 5
x *= 3
print(x)

#5
x = 5
x /= 3
print(x)

#6
x = 5
x %= 3
print(x)

#7
x = 5
x //= 3
print(x)

#8
x = 5
x **= 3
print(x)

#9
x = 5
x &= 3
print(x)

#10
x = 5
x |= 3
print(x)

#11
x = 5
x ^= 3
print(x)

#12
x = 5
x>>= 3
print(x)

#13
x = 5
x <<= 3
print(x)

# %% [markdown]
# comparison operators

# %%
t = 1
u = 2

print(t == u)
print(t != u)
print(t > u)
print(t < u)
print(t >= u)
print(t <= u)
# Out:
# False
# True
# False
# True
# False
# True

# %% [markdown]
# logical operators

# %%
t < 5 and t < 10
# Out:
# True

# %%
t < 5 or t > 4
# Out:
# True

# %%
not(t < 5 and t < 10)
# Out:
# False

# %% [markdown]
# identity operators

# %%
t is u
# Out:
# False

# %%
t is not u
# Out:
# True

# %% [markdown]
# bitwise operators

# %%
v = 2
v << 1
w = v << 2

print(v & w)

15 & 15
# Out:
# 0
# 15
